# %% [markdown]
# # Generate Field Outcome
#  - Given the batter has made contact, and the hit characteristics are given, what happens on the field?
#  - Is the ball caught, do runners advance, is it a home run?
#  - Model must factor in current game state, i.e., bases, etc.
#
# ## Potential Difficulties:
#  - Maybe need to adjust for outfielders?
#  - How to factor stealing in, this also needs to be worked on in the bat outcome as it can happen on strikes/balls?

# %%
from src.data.data_utils import query_mlb_db

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = query_mlb_db("""
select game_pk, inning, inning_topbot, at_bat_number, pitch_number, outs_when_up, post_bat_score - bat_score as runs_scored, stand,
CASE
	WHEN events IN ('single') THEN 'single'
	WHEN events IN ('double') THEN 'double'
	WHEN events IN ('triple') THEN 'triple'
	WHEN events IN ('home_run') THEN 'home_run'
	WHEN events IN ('field_out') THEN 'field_out'
	WHEN events IN ('ground_out', 'force_out') THEN 'ground_out'
	WHEN events IN ('fly_out', 'sac_fly') THEN 'fly_out'
	WHEN events IN ('double_play', 'grounded_into_double_play', 'sac_fly_double_play') THEN 'double_play'
	WHEN events IN ('triple_play') THEN 'triple_play'
	WHEN events IN ('field_error') THEN 'fielding_error'
	WHEN events IN ('fielders_choice') THEN 'fielders_choice'
	ELSE NULL
END AS simplified_outcome,
batter, on_1b, on_2b, on_3b
from Statcast 
where game_year > 2020
and inning < 9 
order by game_date, game_pk, inning, at_bat_number, pitch_number
;
""")

# %%
df[df['simplified_outcome']=='ground_out'][['outs_when_up','stand','on_1b', 'on_2b', 'on_3b']]
# Out:
#          outs_when_up stand     on_1b     on_2b  on_3b
# 9                   0     R  660670.0       NaN    NaN
# 29                  2     R  595909.0  650333.0    NaN
# 91                  2     R  467055.0       NaN    NaN
# 229                 0     R  670156.0  656484.0    NaN
# 302                 1     L  519299.0       NaN    NaN
# ...               ...   ...       ...       ...    ...
# 2551415             0     R  621493.0       NaN    NaN
# 2551543             1     L  663656.0       NaN    NaN
# 2551928             1     R  669134.0       NaN    NaN
# 2551994             1     L  606115.0  621566.0    NaN
# 2552424             1     R  518595.0  542303.0    NaN
#
# [13472 rows x 5 columns]

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 409521 entries, 1 to 2305676
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   game_pk             409521 non-null  int64
#  1   inning              409521 non-null  int64
#  2   inning_topbot       409521 non-null  object
#  3   at_bat_number       409521 non-null  int64
#  4   pitch_number        409521 non-null  int64
#  5   outs_when_up        409521 non-null  int64
#  6   runs_scored         409521 non-null  int64
#  7   stand               409521 non-null  object
#  8   simplified_outcome  409521 non-null  object
#  9   batter              409521 non-null  int64
#  10  on_1b               127155 non-null  float64
#  11  on_2b               76051 non-null   float64
#  12  on_3b               38990 non-null   float64
#  13  outs_after          409521 non-null  int64
#  14  on_1b_after         119232 non-null  float64
#  15  on_2b_after         68476 non-null   float64
#  16  on_3b_after         38227 non-null   float64
# dtypes: float64(6), int64(8), object(3)
# memory usage: 56.2+ MB

# %%
df
# Out:
#          game_pk  inning inning_topbot  at_bat_number  pitch_number  \
# 1         641542       1           Top              1             2
# 2         641542       1           Top              2             1
# 3         641542       1           Top              3             1
# 4         641542       1           Top              4             1
# 9         641542       1           Bot              6             1
# ...          ...     ...           ...            ...           ...
# 2305649   747121       8           Top             59             1
# 2305655   747121       8           Top             60             6
# 2305672   747121       8           Bot             63             6
# 2305674   747121       8           Bot             64             2
# 2305676   747121       8           Bot             65             2
#
#          outs_when_up  runs_scored stand simplified_outcome  batter     on_1b  \
# 1                   0            0     L             single  650333       NaN
# 2                   0            0     L          field_out  595909  650333.0
# 3                   1            0     R          field_out  680777  650333.0
# 4                   2            0     L          field_out  666135  650333.0
# 9                   0            0     R         ground_out  645277  660670.0
# ...               ...          ...   ...                ...     ...       ...
# 2305649             2            0     L             single  595777  650333.0
# 2305655             2            0     L          field_out  630105  595777.0
# 2305672             1            0     R             single  518595  542303.0
# 2305674             1            0     R         ground_out  594807  518595.0
# 2305676             2            0     L          field_out  671739  594807.0
#
#             on_2b     on_3b  outs_after  on_1b_after  on_2b_after  \
# 1             NaN       NaN           0     650333.0          NaN
# 2             NaN       NaN           1     650333.0          NaN
# 3             NaN       NaN           2     650333.0          NaN
# 4             NaN       NaN           3          NaN          NaN
# 9             NaN       NaN           1     645277.0          NaN
# ...           ...       ...         ...          ...          ...
# 2305649       NaN       NaN           2     595777.0     650333.0
# 2305655  650333.0       NaN           3          NaN          NaN
# 2305672       NaN       NaN           1     518595.0     542303.0
# 2305674  542303.0       NaN           2     594807.0          NaN
# 2305676       NaN  542303.0           3          NaN          NaN
#
#          on_3b_after                                    initial_mapping
# 1                NaN  {650333: 'batter', nan: '1b', nan: '2b', nan: ...
# 2                NaN  {595909: 'batter', 650333.0: '1b', nan: '2b', ...
# 3                NaN  {680777: 'batter', 650333.0: '1b', nan: '2b', ...
# 4                NaN  {666135: 'batter', 650333.0: '1b', nan: '2b', ...
# 9                NaN  {645277: 'batter', 660670.0: '1b', nan: '2b', ...
# ...              ...                                                ...
# 2305649          NaN  {595777: 'batter', 650333.0: '1b', nan: '2b', ...
# 2305655          NaN  {630105: 'batter', 595777.0: '1b', 650333.0: '...
# 2305672          NaN  {518595: 'batter', 542303.0: '1b', nan: '2b', ...
# 2305674     542303.0  {594807: 'batter', 518595.0: '1b', 542303.0: '...
# 2305676          NaN  {671739: 'batter', 594807.0: '1b', nan: '2b', ...
#
# [409521 rows x 18 columns]

# %%
df['outs_after'] = df.groupby(['game_pk', 'inning', 'inning_topbot'])['outs_when_up'].shift(-1, fill_value=3)
for col in ('on_1b_after', 'on_2b_after', 'on_3b_after'):
    df[col] = df.groupby(['game_pk', 'inning', 'inning_topbot'])[col[:5]].shift(-1, fill_value=np.nan)

# %%
#only care about hit outcome events
df = df[~df['simplified_outcome'].isna()]

# %%
def create_initial_mapping(row):
    mapping = {
        row['batter']: 'batter',
        row['on_1b']: '1b',
        row['on_2b']: '2b',
        row['on_3b']: '3b'
    }
    return mapping

df['initial_mapping'] = df.apply(create_initial_mapping, axis=1)

# %%
def encode_after_state(row):
    mapping = row['initial_mapping']
    after_state = {
        '1b_after': mapping.get(row['on_1b_after'], False),
        '2b_after': mapping.get(row['on_2b_after'], False),
        '3b_after': mapping.get(row['on_3b_after'], False)
    }
    return after_state

# Apply the function to each row to get the after state encoding
after_states = df.apply(encode_after_state, axis=1)kjjjj

# %%
after_states_df = pd.DataFrame(after_states.tolist())

# %%
# Merge the after states with the original data
data = pd.concat([df.reset_index(drop=True), after_states_df], axis=1)

# %%
data
# Out:
#         game_pk  inning inning_topbot  at_bat_number  pitch_number  \
# 0        641542       1           Top              1             2
# 1        641542       1           Top              2             1
# 2        641542       1           Top              3             1
# 3        641542       1           Top              4             1
# 4        641542       1           Bot              6             1
# ...         ...     ...           ...            ...           ...
# 409516   747121       8           Top             59             1
# 409517   747121       8           Top             60             6
# 409518   747121       8           Bot             63             6
# 409519   747121       8           Bot             64             2
# 409520   747121       8           Bot             65             2
#
#         outs_when_up  runs_scored stand simplified_outcome  batter     on_1b  \
# 0                  0            0     L             single  650333       NaN
# 1                  0            0     L          field_out  595909  650333.0
# 2                  1            0     R          field_out  680777  650333.0
# 3                  2            0     L          field_out  666135  650333.0
# 4                  0            0     R         ground_out  645277  660670.0
# ...              ...          ...   ...                ...     ...       ...
# 409516             2            0     L             single  595777  650333.0
# 409517             2            0     L          field_out  630105  595777.0
# 409518             1            0     R             single  518595  542303.0
# 409519             1            0     R         ground_out  594807  518595.0
# 409520             2            0     L          field_out  671739  594807.0
#
#            on_2b     on_3b  outs_after  on_1b_after  on_2b_after  on_3b_after  \
# 0            NaN       NaN           0     650333.0          NaN          NaN
# 1            NaN       NaN           1     650333.0          NaN          NaN
# 2            NaN       NaN           2     650333.0          NaN          NaN
# 3            NaN       NaN           3          NaN          NaN          NaN
# 4            NaN       NaN           1     645277.0          NaN          NaN
# ...          ...       ...         ...          ...          ...          ...
# 409516       NaN       NaN           2     595777.0     650333.0          NaN
# 409517  650333.0       NaN           3          NaN          NaN          NaN
# 409518       NaN       NaN           1     518595.0     542303.0          NaN
# 409519  542303.0       NaN           2     594807.0          NaN     542303.0
# 409520       NaN  542303.0           3          NaN          NaN          NaN
#
#                                           initial_mapping 1b_after 2b_after  \
# 0       {650333: 'batter', nan: '1b', nan: '2b', nan: ...   batter    False
# 1       {595909: 'batter', 650333.0: '1b', nan: '2b', ...       1b    False
# 2       {680777: 'batter', 650333.0: '1b', nan: '2b', ...       1b    False
# 3       {666135: 'batter', 650333.0: '1b', nan: '2b', ...    False    False
# 4       {645277: 'batter', 660670.0: '1b', nan: '2b', ...   batter    False
# ...                                                   ...      ...      ...
# 409516  {595777: 'batter', 650333.0: '1b', nan: '2b', ...   batter       1b
# 409517  {630105: 'batter', 595777.0: '1b', 650333.0: '...    False    False
# 409518  {518595: 'batter', 542303.0: '1b', nan: '2b', ...   batter       1b
# 409519  {594807: 'batter', 518595.0: '1b', 542303.0: '...   batter    False
# 409520  {671739: 'batter', 594807.0: '1b', nan: '2b', ...    False    False
#
#        3b_after
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 409516    False
# 409517    False
# 409518    False
# 409519       2b
# 409520    False
#
# [409521 rows x 21 columns]

# %%
data['on_1b'] = data['on_1b'].notnull().astype(bool)
data['on_2b'] = data['on_2b'].notnull().astype(bool)
data['on_3b'] = data['on_3b'].notnull().astype(bool)

# %%
def represent_state(row):
    state_before = (row['outs_when_up'], (row['on_1b'], row['on_2b'], row['on_3b']))
    state_after = (row['outs_after'], (row['1b_after'], row['2b_after'], row['3b_after']), row['runs_scored'])
    return state_before, state_after

# Apply the function to get the state representations
data['state_before'], data['state_after'] = zip(*data.apply(represent_state, axis=1))
state_transition_df = data[['simplified_outcome', 'stand', 'state_before', 'state_after']]

# %%
state_transition_df
# Out:
#        simplified_outcome stand                state_before  \
# 0                  single     L  (0, (False, False, False))
# 1               field_out     L   (0, (True, False, False))
# 2               field_out     R   (1, (True, False, False))
# 3               field_out     L   (2, (True, False, False))
# 4              ground_out     R   (0, (True, False, False))
# ...                   ...   ...                         ...
# 409516             single     L   (2, (True, False, False))
# 409517          field_out     L    (2, (True, True, False))
# 409518             single     R   (1, (True, False, False))
# 409519         ground_out     R    (1, (True, True, False))
# 409520          field_out     L    (2, (True, False, True))
#
#                            state_after
# 0       (0, (batter, False, False), 0)
# 1           (1, (1b, False, False), 0)
# 2           (2, (1b, False, False), 0)
# 3        (3, (False, False, False), 0)
# 4       (1, (batter, False, False), 0)
# ...                                ...
# 409516     (2, (batter, 1b, False), 0)
# 409517   (3, (False, False, False), 0)
# 409518     (1, (batter, 1b, False), 0)
# 409519     (2, (batter, False, 2b), 0)
# 409520   (3, (False, False, False), 0)
#
# [409521 rows x 4 columns]

# %%
from collections import defaultdict

def compute_state_transition_probs(df):
    transition_counts = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: defaultdict(int))))

    for row in df.itertuples():
        #event, cur_state, next_state
        transition_counts[row[1]][row[2]][row[3]][row[4]] += 1

    # Convert transition counts to probabilities
    transition_probs = defaultdict(lambda: defaultdict(dict))
    
    #for event, cur_state_dict in transition_counts.items():
    #    for cur_state, next_state_dict in cur_state_dict.items():
    #        total_transitions = sum(next_state_dict.values())
    #        transition_probs[event][cur_state] = {next_state: count / total_transitions for next_state, count in next_state_dict.items()}

    for event, stand_dict in transition_counts.items():
        for stand, cur_state_dict in stand_dict.items():
            for cur_state, next_state_dict in cur_state_dict.items():
                total_transitions = sum(next_state_dict.values())
                transition_probs[event][stand][cur_state] = {next_state: count / total_transitions for next_state, count in next_state_dict.items()}

    return transition_probs


t_probs = compute_state_transition_probs(state_transition_df)

# %%
t_probs['field_out']['R'][(1,(False, False, False))]
# Out:
# {(2, (False, False, False), 0): 1.0}

# %%
from pprint import pprint
def sample_next_state(event, stand, cur_state, transition_probs, print_probs=False):
    if event not in transition_probs or stand not in transition_probs[event] or cur_state not in transition_probs[event][stand]:
        print('ERROR: KEY NOT FOUND')
        return None  # No transitions available for this event and current state

    next_states = list(transition_probs[event][stand][cur_state].keys())
    probabilities = list(transition_probs[event][stand][cur_state].values())

    if print_probs:
        pprint(transition_probs[event][stand][cur_state])
        
    next_state = np.random.choice(len(next_states), p=probabilities)
    return next_states[next_state]

# Example of using the sample_next_state function
event = 'single'
cur_state = (1, (True, False, True))
stand = 'R'
next_state = sample_next_state(event, stand, cur_state, t_probs)
print(next_state)
# Out:
# (1, ('batter', '1b', False), 1)

# %%
import pickle

with open('game_state_t_probs.pkl', 'wb') as f:
    pickle.dump(dict(t_probs), f)

# %%
import pickle
with open('game_state_t_probs.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)

# %%
bases = {'1b': 1, '2b': None, '3b': None}
outs=2

# %%
state_encoded = (outs,tuple(bases[base] is not None for base in ['1b', '2b', '3b']))

# %%
state_encoded
# Out:
# (2, (True, False, False))

# %%
list(loaded_dict['single']['L'][state_encoded].keys())[0]
# Out:
# (2, ('batter', '1b', False), 0)

# %%
sample_next_state('groundout', stand, cur_state, loaded_dict, True)
# Out:
# ERROR: KEY NOT FOUND

# %%
def encode_after_state(row):
    mapping = row['initial_mapping']
    after_state = {
        '1b_after': mapping.get(row['on_1b_after'], np.nan),
        '2b_after': mapping.get(row['on_2b_after'], np.nan),
        '3b_after': mapping.get(row['on_3b_after'], np.nan)
    }
    return after_state

df['initial_mapping'] = df.apply(initial_state_map, axis=1)
after_states = df.apply(encode_after_state, axis=1)
after_states_df = pd.DataFrame(after_states.tolist())

# Merge the after states with the original data
data = pd.concat([df, after_states_df], axis=1)
test = data.drop('initial_mapping', axis=1)[['game_pk','inning', 'inning_topbot', 'at_bat_number', 'pitch_number',
                                             'simplified_outcome',
                                             'runs_scored', 'outs_when_up', 'outs_after',
                                            'batter', 'on_1b', 'on_2b', 'on_3b',
                                            '1b_after', '2b_after', '3b_after', 
                                            ]]
test[~test['simplified_outcome'].isna()].to_csv('test.csv', index=False)

# %%
test2 = test[~test['simplified_outcome'].isna()]
test2['before_state'] = test2.apply(encode_before_state,axis=1)
#test2['after_state'] = test2.apply(encode_after_state, axis=1)
test2[['simplified_outcome', 'before_state']]
# Out:
# /tmp/ipykernel_13920/3351002246.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test2['before_state'] = test2.apply(encode_before_state,axis=1)
#      simplified_outcome       before_state
# 3                single  (0, [1b, 2b, 3b])
# 11               single  (1, [1b, 2b, 3b])
# 15          double_play  (1, [1b, 2b, 3b])
# 18            field_out  (0, [1b, 2b, 3b])
# 20               double  (1, [1b, 2b, 3b])
# ...                 ...                ...
# 9981          field_out  (1, [1b, 2b, 3b])
# 9986             double  (2, [1b, 2b, 3b])
# 9988          field_out  (2, [1b, 2b, 3b])
# 9993          field_out  (0, [1b, 2b, 3b])
# 9996          field_out  (1, [1b, 2b, 3b])
#
# [1717 rows x 2 columns]

# %%
test[~test['simplified_outcome'].isna()]
# Out:
#       game_pk  inning inning_topbot  at_bat_number  pitch_number  \
# 3      490099       1           Top              1             4
# 11     490099       1           Top              3             3
# 15     490099       1           Top              4             4
# 18     490099       1           Bot              5             3
# 20     490099       1           Bot              6             2
# ...       ...     ...           ...            ...           ...
# 9981   490133       2           Bot             14             4
# 9986   490133       2           Bot             15             5
# 9988   490133       2           Bot             16             2
# 9993   490133       3           Top             17             5
# 9996   490133       3           Top             18             3
#
#       outs_when_up  bat_score  batter stand simplified_outcome     on_1b  \
# 3                0          0  656941     L             single       NaN
# 11               1          0  519203     L             single  656941.0
# 15               1          0  450314     L        double_play  519203.0
# 18               0          0  451594     R          field_out       NaN
# 20               1          0  649557     R             double       NaN
# ...            ...        ...     ...   ...                ...       ...
# 9981             1          0  493329     R          field_out       NaN
# 9986             2          0  594828     R             double       NaN
# 9988             2          0  502210     L          field_out       NaN
# 9993             0          0  547982     L          field_out       NaN
# 9996             1          0  516416     R          field_out       NaN
#
#          on_2b  on_3b  outs_after  bat_score_after  on_1b_after  on_2b_after  \
# 3          NaN    NaN           0                0     656941.0          NaN
# 11         NaN    NaN           1                1     519203.0     656941.0
# 15    656941.0    NaN           3                3          NaN          NaN
# 18         NaN    NaN           1                1          NaN          NaN
# 20         NaN    NaN           1                1          NaN     649557.0
# ...        ...    ...         ...              ...          ...          ...
# 9981       NaN    NaN           2                2          NaN          NaN
# 9986       NaN    NaN           2                2          NaN     594828.0
# 9988  594828.0    NaN           3                3          NaN          NaN
# 9993       NaN    NaN           1                1          NaN          NaN
# 9996       NaN    NaN           2                2          NaN          NaN
#
#       on_3b_after 1b_after 2b_after 3b_after
# 3             NaN   batter      NaN      NaN
# 11            NaN   batter       1b      NaN
# 15            NaN      NaN      NaN      NaN
# 18            NaN      NaN      NaN      NaN
# 20            NaN      NaN   batter      NaN
# ...           ...      ...      ...      ...
# 9981          NaN      NaN      NaN      NaN
# 9986          NaN      NaN   batter      NaN
# 9988          NaN      NaN      NaN      NaN
# 9993          NaN      NaN      NaN      NaN
# 9996          NaN      NaN      NaN      NaN
#
# [1717 rows x 21 columns]

# %%
df.head(50)
# Out:
#     game_pk  inning inning_topbot  at_bat_number  pitch_number  outs_when_up  \
# 0    490099       1           Top              1             1             0
# 1    490099       1           Top              1             2             0
# 2    490099       1           Top              1             3             0
# 3    490099       1           Top              1             4             0
# 4    490099       1           Top              2             1             0
# 5    490099       1           Top              2             2             0
# 6    490099       1           Top              2             3             0
# 7    490099       1           Top              2             4             0
# 8    490099       1           Top              2             5             0
# 9    490099       1           Top              3             1             1
# 10   490099       1           Top              3             2             1
# 11   490099       1           Top              3             3             1
# 12   490099       1           Top              4             1             1
# 13   490099       1           Top              4             2             1
# 14   490099       1           Top              4             3             1
# 15   490099       1           Top              4             4             1
# 16   490099       1           Bot              5             1             0
# 17   490099       1           Bot              5             2             0
# 18   490099       1           Bot              5             3             0
# 19   490099       1           Bot              6             1             1
# 20   490099       1           Bot              6             2             1
# 21   490099       1           Bot              7             1             1
# 22   490099       1           Bot              7             2             1
# 23   490099       1           Bot              7             3             1
# 24   490099       1           Bot              7             4             1
# 25   490099       1           Bot              7             5             1
# 26   490099       1           Bot              7             6             1
# 27   490099       1           Bot              8             1             2
# 28   490099       1           Bot              8             2             2
# 29   490099       1           Bot              8             3             2
# 30   490099       1           Bot              8             4             2
# 31   490099       2           Top              9             1             0
# 32   490099       2           Top              9             2             0
# 33   490099       2           Top              9             3             0
# 34   490099       2           Top              9             4             0
# 35   490099       2           Top              9             5             0
# 36   490099       2           Top              9             6             0
# 37   490099       2           Top             10             1             1
# 38   490099       2           Top             10             2             1
# 39   490099       2           Top             10             3             1
# 40   490099       2           Top             11             1             2
# 41   490099       2           Top             11             2             2
# 42   490099       2           Top             11             3             2
# 43   490099       2           Top             11             4             2
# 44   490099       2           Bot             12             1             0
# 45   490099       2           Bot             12             2             0
# 46   490099       2           Bot             12             3             0
# 47   490099       2           Bot             12             4             0
# 48   490099       2           Bot             12             5             0
# 49   490099       2           Bot             12             6             0
#
#     bat_score  batter stand simplified_outcome     on_1b     on_2b     on_3b  \
# 0           0  656941     L               None       NaN       NaN       NaN
# 1           0  656941     L               None       NaN       NaN       NaN
# 2           0  656941     L               None       NaN       NaN       NaN
# 3           0  656941     L             single       NaN       NaN       NaN
# 4           0  592178     R               None  656941.0       NaN       NaN
# 5           0  592178     R               None  656941.0       NaN       NaN
# 6           0  592178     R               None  656941.0       NaN       NaN
# 7           0  592178     R               None  656941.0       NaN       NaN
# 8           0  592178     R               None  656941.0       NaN       NaN
# 9           0  519203     L               None  656941.0       NaN       NaN
# 10          0  519203     L               None  656941.0       NaN       NaN
# 11          0  519203     L             single  656941.0       NaN       NaN
# 12          0  450314     L               None  519203.0  656941.0       NaN
# 13          0  450314     L               None  519203.0  656941.0       NaN
# 14          0  450314     L               None  519203.0  656941.0       NaN
# 15          0  450314     L        double_play  519203.0  656941.0       NaN
# 16          0  451594     R               None       NaN       NaN       NaN
# 17          0  451594     R               None       NaN       NaN       NaN
# 18          0  451594     R          field_out       NaN       NaN       NaN
# 19          0  649557     R               None       NaN       NaN       NaN
# 20          0  649557     R             double       NaN       NaN       NaN
# 21          0  572761     L               None       NaN  649557.0       NaN
# 22          0  572761     L               None       NaN  649557.0       NaN
# 23          0  572761     L               None       NaN  649557.0       NaN
# 24          0  572761     L               None       NaN  649557.0       NaN
# 25          0  572761     L               None       NaN  649557.0       NaN
# 26          0  572761     L          field_out       NaN  649557.0       NaN
# 27          0  425509     R               None       NaN       NaN  649557.0
# 28          0  425509     R               None       NaN       NaN  649557.0
# 29          0  425509     R               None       NaN       NaN  649557.0
# 30          0  425509     R               None       NaN       NaN  649557.0
# 31          0  608365     R               None       NaN       NaN       NaN
# 32          0  608365     R               None       NaN       NaN       NaN
# 33          0  608365     R               None       NaN       NaN       NaN
# 34          0  608365     R               None       NaN       NaN       NaN
# 35          0  608365     R               None       NaN       NaN       NaN
# 36          0  608365     R               None       NaN       NaN       NaN
# 37          0  518792     L               None       NaN       NaN       NaN
# 38          0  518792     L               None       NaN       NaN       NaN
# 39          0  518792     L               None       NaN       NaN       NaN
# 40          0  575929     R               None       NaN       NaN       NaN
# 41          0  575929     R               None       NaN       NaN       NaN
# 42          0  575929     R               None       NaN       NaN       NaN
# 43          0  575929     R               None       NaN       NaN       NaN
# 44          0  425877     R               None       NaN       NaN       NaN
# 45          0  425877     R               None       NaN       NaN       NaN
# 46          0  425877     R               None       NaN       NaN       NaN
# 47          0  425877     R               None       NaN       NaN       NaN
# 48          0  425877     R               None       NaN       NaN       NaN
# 49          0  425877     R             single       NaN       NaN       NaN
#
#     outs_after  bat_score_after  on_1b_after  on_2b_after  on_3b_after
# 0            0                0          NaN          NaN          NaN
# 1            0                0          NaN          NaN          NaN
# 2            0                0          NaN          NaN          NaN
# 3            0                0     656941.0          NaN          NaN
# 4            0                0     656941.0          NaN          NaN
# 5            0                0     656941.0          NaN          NaN
# 6            0                0     656941.0          NaN          NaN
# 7            0                0     656941.0          NaN          NaN
# 8            1                1     656941.0          NaN          NaN
# 9            1                1     656941.0          NaN          NaN
# 10           1                1     656941.0          NaN          NaN
# 11           1                1     519203.0     656941.0          NaN
# 12           1                1     519203.0     656941.0          NaN
# 13           1                1     519203.0     656941.0          NaN
# 14           1                1     519203.0     656941.0          NaN
# 15           3                3          NaN          NaN          NaN
# 16           0                0          NaN          NaN          NaN
# 17           0                0          NaN          NaN          NaN
# 18           1                1          NaN          NaN          NaN
# 19           1                1          NaN          NaN          NaN
# 20           1                1          NaN     649557.0          NaN
# 21           1                1          NaN     649557.0          NaN
# 22           1                1          NaN     649557.0          NaN
# 23           1                1          NaN     649557.0          NaN
# 24           1                1          NaN     649557.0          NaN
# 25           1                1          NaN     649557.0          NaN
# 26           2                2          NaN          NaN     649557.0
# 27           2                2          NaN          NaN     649557.0
# 28           2                2          NaN          NaN     649557.0
# 29           2                2          NaN          NaN     649557.0
# 30           3                3          NaN          NaN          NaN
# 31           0                0          NaN          NaN          NaN
# 32           0                0          NaN          NaN          NaN
# 33           0                0          NaN          NaN          NaN
# 34           0                0          NaN          NaN          NaN
# 35           0                0          NaN          NaN          NaN
# 36           1                1          NaN          NaN          NaN
# 37           1                1          NaN          NaN          NaN
# 38           1                1          NaN          NaN          NaN
# 39           2                2          NaN          NaN          NaN
# 40           2                2          NaN          NaN          NaN
# 41           2                2          NaN          NaN          NaN
# 42           2                2          NaN          NaN          NaN
# 43           3                3          NaN          NaN          NaN
# 44           0                0          NaN          NaN          NaN
# 45           0                0          NaN          NaN          NaN
# 46           0                0          NaN          NaN          NaN
# 47           0                0          NaN          NaN          NaN
# 48           0                0          NaN          NaN          NaN
# 49           0                0     425877.0          NaN          NaN

# %%
import pandas as pd
import numpy as np

# Sample game states representation
# (outs, [first_base, second_base, third_base])
initial_state = (0, [1, 0, 0])  # 0 outs, runner on first

# Load your Statcast data
data = pd.read_csv('statcast_data.csv')

# Assuming you have the necessary columns in your data
# 'launch_speed', 'launch_angle', 'spray_angle', 'batter_speed', 'runner_speed', 'event', 'outs_before', 'runners_before', 'outs_after', 'runners_after'

# Define a function to compute transition probabilities
def compute_transition_probabilities(data):
    transition_counts = {}
    transition_probs = {}
    
    for idx, row in data.iterrows():
        state_before = (row['outs_before'], tuple(row['runners_before']))
        state_after = (row['outs_after'], tuple(row['runners_after']))
        event = row['event']
        
        if state_before not in transition_counts:
            transition_counts[state_before] = {}
        if state_after not in transition_counts[state_before]:
            transition_counts[state_before][state_after] = 0
        
        transition_counts[state_before][state_after] += 1
    
    # Convert counts to probabilities
    for state_before in transition_counts:
        total_transitions = sum(transition_counts[state_before].values())
        transition_probs[state_before] = {state_after: count / total_transitions
                                          for state_after, count in transition_counts[state_before].items()}
    
    return transition_probs

transition_probs = compute_transition_probabilities(data)

# Define a function to simulate game state transitions
def simulate_game_state(initial_state, event, transition_probs):
    state = initial_state
    
    if state in transition_probs:
        possible_transitions = transition_probs[state]
        next_states = list(possible_transitions.keys())
        probabilities = list(possible_transitions.values())
        
        next_state = np.random.choice(next_states, p=probabilities)
        return next_state
    else:
        # Handle unseen states or edge cases
        return state

# Example simulation
current_state = initial_state
event = 'single'  # Example event

# Assuming batter speed and runner speeds are taken into account when generating probabilities
next_state = simulate_game_state(current_state, event, transition_probs)
print("Next State:", next_state)
